# %%
#imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('data/diamonds_train.csv')

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40455 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40455 non-null  float64
#  1   cut      40455 non-null  object
#  2   color    40455 non-null  object
#  3   clarity  40455 non-null  object
#  4   depth    40455 non-null  float64
#  5   table    40455 non-null  float64
#  6   price    40455 non-null  int64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
#Carat = Unit of weight for gemstones
carat_unique = data['carat'].unique()
carat_unique.sort()
carat_unique
# Out:
# array([0.2 , 0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 ,
#        0.31, 0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41,
#        0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52,
#        0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63,
#        0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74,
#        0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82, 0.83, 0.84, 0.85,
#        0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96,
#        0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03, 1.04, 1.05, 1.06, 1.07,
#        1.08, 1.09, 1.1 , 1.11, 1.12, 1.13, 1.14, 1.15, 1.16, 1.17, 1.18,
#        1.19, 1.2 , 1.21, 1.22, 1.23, 1.24, 1.25, 1.26, 1.27, 1.28, 1.29,
#        1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37, 1.38, 1.39, 1.4 ,
#        1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48, 1.49, 1.5 , 1.51,
#        1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59, 1.6 , 1.61, 1.62,
# ...

# %%
#Cut = quality of the cut (Fair, Good, Very Good, Premium, Ideal)
cut_unique = data['cut'].unique()
cut_unique.sort()
cut_unique
# Out:
# array(['Fair', 'Good', 'Ideal', 'Premium', 'Very Good'], dtype=object)

# %%
#Color = diamond colour, from J (worst) to D (best)
color_unique = data['color'].unique()
color_unique.sort()
color_unique
# Out:
# array(['D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype=object)

# %%
#Clarity = measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
clarity_unique = data['clarity'].unique()
clarity_unique.sort()
clarity_unique
# Out:
# array(['I1', 'IF', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2'],
#       dtype=object)

# %%
#
depth_unique = data['depth'].unique()
depth_unique.sort()
depth_unique
# Out:
# array([43. , 44. , 52.3, 52.7, 53.3, 53.4, 53.8, 54. , 54.2, 54.3, 54.4,
#        54.6, 54.7, 55. , 55.1, 55.2, 55.3, 55.4, 55.5, 55.6, 55.8, 55.9,
#        56. , 56.1, 56.2, 56.3, 56.4, 56.5, 56.6, 56.7, 56.8, 56.9, 57. ,
#        57.1, 57.2, 57.3, 57.4, 57.5, 57.6, 57.7, 57.8, 57.9, 58. , 58.1,
#        58.2, 58.3, 58.4, 58.5, 58.6, 58.7, 58.8, 58.9, 59. , 59.1, 59.2,
#        59.3, 59.4, 59.5, 59.6, 59.7, 59.8, 59.9, 60. , 60.1, 60.2, 60.3,
#        60.4, 60.5, 60.6, 60.7, 60.8, 60.9, 61. , 61.1, 61.2, 61.3, 61.4,
#        61.5, 61.6, 61.7, 61.8, 61.9, 62. , 62.1, 62.2, 62.3, 62.4, 62.5,
#        62.6, 62.7, 62.8, 62.9, 63. , 63.1, 63.2, 63.3, 63.4, 63.5, 63.6,
#        63.7, 63.8, 63.9, 64. , 64.1, 64.2, 64.3, 64.4, 64.5, 64.6, 64.7,
#        64.8, 64.9, 65. , 65.1, 65.2, 65.3, 65.4, 65.5, 65.6, 65.7, 65.8,
#        65.9, 66. , 66.1, 66.2, 66.3, 66.4, 66.5, 66.6, 66.7, 66.8, 66.9,
#        67. , 67.1, 67.2, 67.3, 67.4, 67.5, 67.6, 67.7, 67.8, 67.9, 68. ,
# ...

# %%
#Table = width of top of diamond relative to widest point (43--95)
table_unique = data['table'].unique()
table_unique.sort()
table_unique
# Out:
# array([43. , 44. , 49. , 50. , 50.1, 51. , 52. , 52.4, 52.8, 53. , 53.1,
#        53.2, 53.3, 53.4, 53.5, 53.6, 53.7, 53.8, 53.9, 54. , 54.1, 54.2,
#        54.3, 54.4, 54.5, 54.6, 54.7, 54.8, 54.9, 55. , 55.1, 55.2, 55.3,
#        55.4, 55.5, 55.6, 55.7, 55.8, 55.9, 56. , 56.1, 56.2, 56.3, 56.4,
#        56.5, 56.6, 56.7, 56.8, 56.9, 57. , 57.1, 57.2, 57.3, 57.4, 57.5,
#        57.6, 57.7, 57.8, 57.9, 58. , 58.1, 58.2, 58.3, 58.4, 58.5, 58.6,
#        58.7, 58.8, 58.9, 59. , 59.1, 59.2, 59.3, 59.4, 59.5, 59.6, 59.7,
#        59.8, 59.9, 60. , 60.1, 60.2, 60.3, 60.4, 60.5, 60.6, 60.7, 60.8,
#        60.9, 61. , 61.2, 61.3, 61.4, 61.5, 61.7, 61.8, 61.9, 62. , 62.2,
#        62.3, 62.4, 62.5, 62.6, 62.8, 63. , 63.3, 63.4, 63.5, 64. , 64.2,
#        64.3, 65. , 66. , 67. , 68. , 69. , 70. , 73. , 76. , 79. , 95. ])

# %%
price_unique = data['price'].unique()
price_unique.sort()
price_unique
# Out:
# array([  326,   327,   334, ..., 18806, 18818, 18823])

# %%
null_cols = data.isnull().sum()
null_cols
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
data['price']
# Out:
# 0         4268
# 1          505
# 2         2686
# 3          738
# 4         4882
#          ...
# 40450    10070
# 40451    12615
# 40452     5457
# 40453      456
# 40454     6232
# Name: price, Length: 40455, dtype: int64

# %%
#x = length in mm
x_unique = data['x'].unique()
x_unique.sort()
x_unique
# Out:
# array([ 0.  ,  3.77,  3.79,  3.81,  3.82,  3.83,  3.84,  3.85,  3.86,
#         3.87,  3.88,  3.89,  3.9 ,  3.91,  3.92,  3.93,  3.94,  3.95,
#         3.96,  3.97,  3.98,  3.99,  4.  ,  4.01,  4.02,  4.03,  4.04,
#         4.05,  4.06,  4.07,  4.08,  4.09,  4.1 ,  4.11,  4.12,  4.13,
#         4.14,  4.15,  4.16,  4.17,  4.18,  4.19,  4.2 ,  4.21,  4.22,
#         4.23,  4.24,  4.25,  4.26,  4.27,  4.28,  4.29,  4.3 ,  4.31,
#         4.32,  4.33,  4.34,  4.35,  4.36,  4.37,  4.38,  4.39,  4.4 ,
#         4.41,  4.42,  4.43,  4.44,  4.45,  4.46,  4.47,  4.48,  4.49,
#         4.5 ,  4.51,  4.52,  4.53,  4.54,  4.55,  4.56,  4.57,  4.58,
#         4.59,  4.6 ,  4.61,  4.62,  4.63,  4.64,  4.65,  4.66,  4.67,
#         4.68,  4.69,  4.7 ,  4.71,  4.72,  4.73,  4.74,  4.75,  4.76,
#         4.77,  4.78,  4.79,  4.8 ,  4.81,  4.82,  4.83,  4.84,  4.85,
#         4.86,  4.87,  4.88,  4.89,  4.9 ,  4.91,  4.92,  4.93,  4.94,
# ...

# %%
#y = width in mm
y_unique = data['y'].unique()
y_unique.sort()
y_unique
# Out:
# array([ 0.  ,  3.72,  3.75,  3.77,  3.78,  3.8 ,  3.81,  3.82,  3.83,
#         3.84,  3.85,  3.86,  3.87,  3.88,  3.89,  3.9 ,  3.91,  3.92,
#         3.93,  3.94,  3.95,  3.96,  3.97,  3.98,  3.99,  4.  ,  4.01,
#         4.02,  4.03,  4.04,  4.05,  4.06,  4.07,  4.08,  4.09,  4.1 ,
#         4.11,  4.12,  4.13,  4.14,  4.15,  4.16,  4.17,  4.18,  4.19,
#         4.2 ,  4.21,  4.22,  4.23,  4.24,  4.25,  4.26,  4.27,  4.28,
#         4.29,  4.3 ,  4.31,  4.32,  4.33,  4.34,  4.35,  4.36,  4.37,
#         4.38,  4.39,  4.4 ,  4.41,  4.42,  4.43,  4.44,  4.45,  4.46,
#         4.47,  4.48,  4.49,  4.5 ,  4.51,  4.52,  4.53,  4.54,  4.55,
#         4.56,  4.57,  4.58,  4.59,  4.6 ,  4.61,  4.62,  4.63,  4.64,
#         4.65,  4.66,  4.67,  4.68,  4.69,  4.7 ,  4.71,  4.72,  4.73,
#         4.74,  4.75,  4.76,  4.77,  4.78,  4.79,  4.8 ,  4.81,  4.82,
#         4.83,  4.84,  4.85,  4.86,  4.87,  4.88,  4.89,  4.9 ,  4.91,
# ...

# %%
#z = depth in mm
z_unique = data['z'].unique()
z_unique.sort()
z_unique
# Out:
# array([0.  , 1.07, 1.53, 2.06, 2.25, 2.26, 2.27, 2.28, 2.29, 2.3 , 2.31,
#        2.32, 2.33, 2.34, 2.35, 2.36, 2.37, 2.38, 2.39, 2.4 , 2.41, 2.42,
#        2.43, 2.44, 2.45, 2.46, 2.47, 2.48, 2.49, 2.5 , 2.51, 2.52, 2.53,
#        2.54, 2.55, 2.56, 2.57, 2.58, 2.59, 2.6 , 2.61, 2.62, 2.63, 2.64,
#        2.65, 2.66, 2.67, 2.68, 2.69, 2.7 , 2.71, 2.72, 2.73, 2.74, 2.75,
#        2.76, 2.77, 2.78, 2.79, 2.8 , 2.81, 2.82, 2.83, 2.84, 2.85, 2.86,
#        2.87, 2.88, 2.89, 2.9 , 2.91, 2.92, 2.93, 2.94, 2.95, 2.96, 2.97,
#        2.98, 2.99, 3.  , 3.01, 3.02, 3.03, 3.04, 3.05, 3.06, 3.07, 3.08,
#        3.09, 3.1 , 3.11, 3.12, 3.13, 3.14, 3.15, 3.16, 3.17, 3.18, 3.19,
#        3.2 , 3.21, 3.22, 3.23, 3.24, 3.25, 3.26, 3.27, 3.28, 3.29, 3.3 ,
#        3.31, 3.32, 3.33, 3.34, 3.35, 3.36, 3.37, 3.38, 3.39, 3.4 , 3.41,
#        3.42, 3.43, 3.44, 3.45, 3.46, 3.47, 3.48, 3.49, 3.5 , 3.51, 3.52,
#        3.53, 3.54, 3.55, 3.56, 3.57, 3.58, 3.59, 3.6 , 3.61, 3.62, 3.63,
# ...

# %%
data.describe(include='all')
# Out:
#                carat    cut  color clarity         depth         table  \
# count   40455.000000  40455  40455   40455  40455.000000  40455.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  16220   8455    9749           NaN           NaN
# mean        0.797706    NaN    NaN     NaN     61.752841     57.446133
# std         0.475544    NaN    NaN     NaN      1.431725      2.233535
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         4.500000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# ...

# %%
data.boxplot(figsize=(18, 18))
# Out:
# <AxesSubplot:>

# %%
stats = data.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#          count         mean          std    min     25%      50%       75%  \
# carat  40455.0     0.797706     0.475544    0.2    0.40     0.70     1.040
# depth  40455.0    61.752841     1.431725   43.0   61.00    61.80    62.500
# table  40455.0    57.446133     2.233535   43.0   56.00    57.00    59.000
# price  40455.0  3928.444469  3992.416147  326.0  945.00  2397.00  5331.000
# x      40455.0     5.729392     1.124453    0.0    4.71     5.69     6.540
# y      40455.0     5.732819     1.146650    0.0    4.72     5.71     6.540
# z      40455.0     3.537154     0.697062    0.0    2.91     3.52     4.035
#
#             max       IQR
# carat      4.50     0.640
# depth     79.00     1.500
# table     95.00     3.000
# price  18823.00  4386.000
# x         10.23     1.830
# y         58.90     1.820
# z          8.06     1.125

# %%
data['carat'].hist()
# Out:
# <AxesSubplot:>

# %%
data['cut'].hist()
# Out:
# <AxesSubplot:>

# %%
data['color'].hist()
# Out:
# <AxesSubplot:>

# %%
data['clarity'].hist()
# Out:
# <AxesSubplot:>

# %%
data['depth'].hist()
# Out:
# <AxesSubplot:>

# %%
data['table'].hist()
# Out:
# <AxesSubplot:>

# %%
data['price'].hist()
# Out:
# <AxesSubplot:>

# %%
data['x'].hist()
# Out:
# <AxesSubplot:>

# %%
data['y'].hist()
# Out:
# <AxesSubplot:>

# %%
data['z'].hist()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,8))
ax.barh(data['price'], data['carat']);

# %%
fig, ax = plt.subplots()
ax.barh(data['price'], data['carat']);

# %%
fig, ax = plt.subplots()
ax.barh(data['cut'], data['color']);

# %%
#Seaborn
plt.style.use('default')
sns.set_style('white')

# %%
column_cut = data['cut']
column_price = data['price']

# %%
sns.lineplot(data=data, x = column_cut, y = column_price)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
pd.plotting.scatter_matrix(data, figsize=(20,10))
# Out:
# array([[<AxesSubplot:xlabel='carat', ylabel='carat'>,
#         <AxesSubplot:xlabel='depth', ylabel='carat'>,
#         <AxesSubplot:xlabel='table', ylabel='carat'>,
#         <AxesSubplot:xlabel='price', ylabel='carat'>,
#         <AxesSubplot:xlabel='x', ylabel='carat'>,
#         <AxesSubplot:xlabel='y', ylabel='carat'>,
#         <AxesSubplot:xlabel='z', ylabel='carat'>],
#        [<AxesSubplot:xlabel='carat', ylabel='depth'>,
#         <AxesSubplot:xlabel='depth', ylabel='depth'>,
#         <AxesSubplot:xlabel='table', ylabel='depth'>,
#         <AxesSubplot:xlabel='price', ylabel='depth'>,
#         <AxesSubplot:xlabel='x', ylabel='depth'>,
#         <AxesSubplot:xlabel='y', ylabel='depth'>,
#         <AxesSubplot:xlabel='z', ylabel='depth'>],
#        [<AxesSubplot:xlabel='carat', ylabel='table'>,
#         <AxesSubplot:xlabel='depth', ylabel='table'>,
#         <AxesSubplot:xlabel='table', ylabel='table'>,
#         <AxesSubplot:xlabel='price', ylabel='table'>,
# ...

# %%
column_clarity = data['clarity']
column_color = data['color']

# %%
data.plot.scatter(x = 'clarity', y = 'color', alpha=0.2, grid=True)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='color'>

# %%
data.plot.scatter(x = 'clarity', y = 'price', alpha=0.2, grid=True)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
data.plot.scatter(x = 'color', y = 'price', alpha=0.2, grid=True)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
cmap = sns.cubehelix_palette(as_cmap=True)
data.plot.scatter(x="cut", y="price", c="carat", cmap=cmap, alpha=0.2, grid=True)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
data["x*y*z"] = data["x"] * data["y"] * data["z"]

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
#
#         x*y*z
# 0  197.096725
# 1   52.395750
# 2  113.436890
# 3   66.268800
# 4  168.429975

# %%
#I want to give names that are more easily understood, from best to worse cut

data['cut'] = data['cut'].replace(['Ideal'],'1-Ideal')
data['cut'] = data['cut'].replace(['Premium'],'2-Premium')
data['cut'] = data['cut'].replace(['Very Good'],'3-Very Good')
data['cut'] = data['cut'].replace(['Good'],'4-Good')
data['cut'] = data['cut'].replace(['Fair'],'5-Fair')

# %%
data.head()
# Out:
#    carat          cut color clarity  depth  table  price     x     y     z  \
# 0   1.21    2-Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  3-Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       5-Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       4-Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      1-Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
#
#         x*y*z
# 0  197.096725
# 1   52.395750
# 2  113.436890
# 3   66.268800
# 4  168.429975

# %%
#I want to give names that are more easily understood, from best to worse color: 'D', 'E', 'F', 'G', 'H', 'I', 'J'

data['color'] = data['color'].replace(['D'],'1-D')
data['color'] = data['color'].replace(['E'],'2-E')
data['color'] = data['color'].replace(['F'],'3-F')
data['color'] = data['color'].replace(['G'],'4-G')
data['color'] = data['color'].replace(['H'],'5-H')
data['color'] = data['color'].replace(['I'],'6-I')
data['color'] = data['color'].replace(['J'],'7-J')

# %%
data.head()
# Out:
#    carat          cut color clarity  depth  table  price     x     y     z  \
# 0   1.21    2-Premium   7-J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  3-Very Good   5-H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       5-Fair   4-G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       4-Good   1-D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      1-Ideal   4-G     SI1   60.5   59.0   4882  6.55  6.51  3.95
#
#         x*y*z
# 0  197.096725
# 1   52.395750
# 2  113.436890
# 3   66.268800
# 4  168.429975

# %%
data['color'].unique()
# Out:
# array(['7-J', '5-H', '4-G', '1-D', '3-F', '2-E', '6-I'], dtype=object)

# %%
data['clarity'].unique()
# Out:
# array(['VS2', 'VS1', 'SI1', 'SI2', 'IF', 'VVS1', 'VVS2', 'I1'],
#       dtype=object)

# %%
data['clarity'] = data['clarity'].replace(['IF'],'1-IF')
data['clarity'] = data['clarity'].replace(['VVS1'],'2-VVS1')
data['clarity'] = data['clarity'].replace(['VVS2'],'3-VVS2')
data['clarity'] = data['clarity'].replace(['VS1'],'4-VS1')
data['clarity'] = data['clarity'].replace(['VS2'],'5-VS2')
data['clarity'] = data['clarity'].replace(['SI1'],'6-SI1')
data['clarity'] = data['clarity'].replace(['SI2'],'7-SI2')
data['clarity'] = data['clarity'].replace(['I1'],'8-I1')

# %%
data['clarity'].unique()
# Out:
# array(['5-VS2', '4-VS1', '6-SI1', '7-SI2', '1-IF', '2-VVS1', '3-VVS2',
#        '8-I1'], dtype=object)

# %%
data.to_csv('diamonds_train_new.csv', index=False)
